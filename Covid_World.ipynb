# %%
# Import liabraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes = True)

# %%
# Import the data 

covid = pd.read_csv(r'C:\Users\Vatsal Jansari\Desktop\Data Analysis Projects\Covid In python\Country-wise-COVID-cases.csv')

# %%
covid
# Out:
#          Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 0                 USA        47916190        783565       37918301.0      1.6
# 1               India        34447536        463655       33849785.0      1.3
# 2              Brazil        21957967        611318       21151342.0      2.8
# 3                  UK         9561099        142898        7825200.0      1.5
# 4              Russia         9109094        256597        7812557.0      2.8
# ..                ...             ...           ...              ...      ...
# 207           Vanuatu               6             1              3.0     16.7
# 208  Marshall Islands               4             0              4.0      0.0
# 209             Samoa               3             0              3.0      0.0
# 210        Micronesia               1             0              1.0      0.0
# 211             Tonga               1             0              NaN      0.0
#
#      Recovered %
# ...

# %%
covid.head()
# Out:
#   Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 0          USA        47916190        783565       37918301.0      1.6
# 1        India        34447536        463655       33849785.0      1.3
# 2       Brazil        21957967        611318       21151342.0      2.8
# 3           UK         9561099        142898        7825200.0      1.5
# 4       Russia         9109094        256597        7812557.0      2.8
#
#    Recovered %
# 0         79.1
# 1         98.3
# 2         96.3
# 3         81.8
# 4         85.8

# %%
covid.tail()
# Out:
#          Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 207           Vanuatu               6             1              3.0     16.7
# 208  Marshall Islands               4             0              4.0      0.0
# 209             Samoa               3             0              3.0      0.0
# 210        Micronesia               1             0              1.0      0.0
# 211             Tonga               1             0              NaN      0.0
#
#      Recovered %
# 207         50.0
# 208        100.0
# 209        100.0
# 210        100.0
# 211          0.0

# %%
covid.head(1)
# Out:
#   Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 0          USA        47916190        783565       37918301.0      1.6
#
#    Recovered %
# 0         79.1

# %%
covid.tail(1)
# Out:
#     Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 211        Tonga               1             0              NaN      0.0
#
#      Recovered %
# 211          0.0

# %%
covid.dtypes
# Out:
# Country Name        object
# Total Infected       int64
# Total Deaths         int64
# Total Recovered    float64
# Death %            float64
# Recovered %        float64
# dtype: object

# %%
#Column Names

covid.columns
# Out:
# Index(['Country Name', 'Total Infected', 'Total Deaths', 'Total Recovered',
#        'Death %', 'Recovered %'],
#       dtype='object')

# %%
#Summary of Dataset

covid.describe()
# Out:
#        Total Infected   Total Deaths  Total Recovered     Death %  Recovered %
# count    2.120000e+02     212.000000     2.110000e+02  212.000000   212.000000
# mean     1.198016e+06   24131.419811     1.088647e+06    2.031604    85.644340
# std      4.496011e+06   83029.117720     3.953385e+06    2.184476    21.942024
# min      1.000000e+00       0.000000     1.000000e+00    0.000000     0.000000
# 25%      1.579950e+04     191.250000     1.213050e+04    0.900000    85.475000
# 50%      1.280125e+05    1888.000000     1.027160e+05    1.500000    94.750000
# 75%      5.756202e+05   11267.500000     5.314445e+05    2.500000    97.200000
# max      4.791619e+07  783565.000000     3.791830e+07   19.400000   100.000000

# %%
covid.hist(figsize=(10,20))
# Out:
# array([[<Axes: title={'center': 'Total Infected'}>,
#         <Axes: title={'center': 'Total Deaths'}>],
#        [<Axes: title={'center': 'Total Recovered'}>,
#         <Axes: title={'center': 'Death %'}>],
#        [<Axes: title={'center': 'Recovered %'}>, <Axes: >]], dtype=object)

# %%
vc = covid.head()
# Out:
#   Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 0          USA        47916190        783565       37918301.0      1.6
# 1        India        34447536        463655       33849785.0      1.3
# 2       Brazil        21957967        611318       21151342.0      2.8
# 3           UK         9561099        142898        7825200.0      1.5
# 4       Russia         9109094        256597        7812557.0      2.8
#
#    Recovered %
# 0         79.1
# 1         98.3
# 2         96.3
# 3         81.8
# 4         85.8

# %%
 
u = covid.drop(['Death %','Recovered %'], axis =1)

# %%
u
# Out:
#          Country Name  Total Infected  Total Deaths  Total Recovered
# 0                 USA        47916190        783565       37918301.0
# 1               India        34447536        463655       33849785.0
# 2              Brazil        21957967        611318       21151342.0
# 3                  UK         9561099        142898        7825200.0
# 4              Russia         9109094        256597        7812557.0
# ..                ...             ...           ...              ...
# 207           Vanuatu               6             1              3.0
# 208  Marshall Islands               4             0              4.0
# 209             Samoa               3             0              3.0
# 210        Micronesia               1             0              1.0
# 211             Tonga               1             0              NaN
#
# [212 rows x 4 columns]

# %%
v = u.head(5)

# %%
v
# Out:
#   Country Name  Total Infected  Total Deaths  Total Recovered
# 0          USA        47916190        783565       37918301.0
# 1        India        34447536        463655       33849785.0
# 2       Brazil        21957967        611318       21151342.0
# 3           UK         9561099        142898        7825200.0
# 4       Russia         9109094        256597        7812557.0

# %%
v.hist(x)
# Out:
# array([[<Axes: title={'center': 'Total Infected'}>,
#         <Axes: title={'center': 'Total Deaths'}>],
#        [<Axes: title={'center': 'Total Recovered'}>, <Axes: >]],
#       dtype=object)

# %%
v
# Out:
#   Country Name  Total Infected  Total Deaths  Total Recovered
# 0          USA        47916190        783565       37918301.0
# 1        India        34447536        463655       33849785.0
# 2       Brazil        21957967        611318       21151342.0
# 3           UK         9561099        142898        7825200.0
# 4       Russia         9109094        256597        7812557.0

# %%
a= v['Country Name']

# %%
a
# Out:
# 0       USA
# 1     India
# 2    Brazil
# 3        UK
# 4    Russia
# Name: Country Name, dtype: object

# %%
b= v['Total Infected']

# %%
b
# Out:
# 0    47916190
# 1    34447536
# 2    21957967
# 3     9561099
# 4     9109094
# Name: Total Infected, dtype: int64

# %%
# Top 5 contries Infected.
plt.bar(a,b)
# Out:
# <BarContainer object of 5 artists>

# %%
IU = covid.head(2)

# %%
IU
# Out:
#   Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 0          USA        47916190        783565       37918301.0      1.6
# 1        India        34447536        463655       33849785.0      1.3
#
#    Recovered %
# 0         79.1
# 1         98.3

# %%
I = IU['Country Name']
U = IU['Recovered %']

# %%
#Comparing USA and INDIA recovered rate.

plt.bar(I,U)
# Out:
# <BarContainer object of 2 artists>

# %%
# Removing Duplicates

Covid = covid.drop_duplicates()

# %%
#Dataset Size

Covid.size
# Out:
# 1272

# %%
Covid
# Out:
#          Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 0                 USA        47916190        783565       37918301.0      1.6
# 1               India        34447536        463655       33849785.0      1.3
# 2              Brazil        21957967        611318       21151342.0      2.8
# 3                  UK         9561099        142898        7825200.0      1.5
# 4              Russia         9109094        256597        7812557.0      2.8
# ..                ...             ...           ...              ...      ...
# 207           Vanuatu               6             1              3.0     16.7
# 208  Marshall Islands               4             0              4.0      0.0
# 209             Samoa               3             0              3.0      0.0
# 210        Micronesia               1             0              1.0      0.0
# 211             Tonga               1             0              NaN      0.0
#
#      Recovered %
# ...

# %%
covid.head()
# Out:
#   Country Name  Total Infected  Total Deaths  Total Recovered  Death %  \
# 0          USA        47916190        783565       37918301.0      1.6
# 1        India        34447536        463655       33849785.0      1.3
# 2       Brazil        21957967        611318       21151342.0      2.8
# 3           UK         9561099        142898        7825200.0      1.5
# 4       Russia         9109094        256597        7812557.0      2.8
#
#    Recovered %
# 0         79.1
# 1         98.3
# 2         96.3
# 3         81.8
# 4         85.8

# %%
Covid.isnull().sum()
# Out:
# Country Name       0
# Total Infected     0
# Total Deaths       0
# Total Recovered    1
# Death %            0
# Recovered %        0
# dtype: int64

# %%
#Drop the null values

Covid = Covid.dropna()
Covid.count()
# Out:
# Country Name       211
# Total Infected     211
# Total Deaths       211
# Total Recovered    211
# Death %            211
# Recovered %        211
# dtype: int64

# %%
Covid.isnull().sum()
# Out:
# Country Name       0
# Total Infected     0
# Total Deaths       0
# Total Recovered    0
# Death %            0
# Recovered %        0
# dtype: int64

# %%
#Top 5 infected Countries.

Covid1 = covid.sort_values('TotalInfected',ascending=False).head()

# %%
Covid1
# Out:
#   Country Name  TotalInfected  Total Deaths  Total Recovered  Death %  \
# 0          USA       47916190        783565       37918301.0      1.6
# 1        India       34447536        463655       33849785.0      1.3
# 2       Brazil       21957967        611318       21151342.0      2.8
# 3           UK        9561099        142898        7825200.0      1.5
# 4       Russia        9109094        256597        7812557.0      2.8
#
#    Recovered %
# 0         79.1
# 1         98.3
# 2         96.3
# 3         81.8
# 4         85.8

# %%
covid
# Out:
#          Country Name  TotalInfected  Total Deaths  Total Recovered  Death %  \
# 0                 USA       47916190        783565       37918301.0      1.6
# 1               India       34447536        463655       33849785.0      1.3
# 2              Brazil       21957967        611318       21151342.0      2.8
# 3                  UK        9561099        142898        7825200.0      1.5
# 4              Russia        9109094        256597        7812557.0      2.8
# ..                ...            ...           ...              ...      ...
# 207           Vanuatu              6             1              3.0     16.7
# 208  Marshall Islands              4             0              4.0      0.0
# 209             Samoa              3             0              3.0      0.0
# 210        Micronesia              1             0              1.0      0.0
# 211             Tonga              1             0              NaN      0.0
#
#      Recovered %
# 0           79.1
# ...

# %%
#Top 10 Infected Numbers

q= covid.TotalInfected.nlargest(10)
# Out:
# 0    47916190
# 1    34447536
# 2    21957967
# 3     9561099
# 4     9109094
# 5     8408166
# 6     7287645
# 7     6045212
# 8     5305742
# 9     5047156
# Name: TotalInfected, dtype: int64

# %%
#Total Infected in all over the world as per dataset.

covid.TotalInfected.sum()
# Out:
# 253979437
